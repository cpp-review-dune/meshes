# %% [markdown]
# # [Tutorials](https://gitlab.onelab.info/gmsh/gmsh/-/tree/gmsh_4_12_0/tutorials/julia)

# %%
run(`gmsh --version`)
# Out:
# 4.12.0
# Process(`gmsh --version`, ProcessExited(0))

# %%
using gmsh

# %% [markdown]
# #### [`t1.jl`](https://gitlab.onelab.info/gmsh/gmsh/-/blob/gmsh_4_12_0/tutorials/julia/t1.jl)

# %%
gmsh.initialize()
gmsh.option.setNumber("General.Terminal", 1)
gmsh.model.add("t1")
lc = 1e-2
gmsh.model.geo.addPoint(0, 0, 0, lc, 1)
gmsh.model.geo.addPoint(.1, 0,  0, lc, 2)
gmsh.model.geo.addPoint(.1, .3, 0, lc, 3)
gmsh.model.geo.addPoint(0, .3, 0, lc, 4)
gmsh.model.geo.addLine(1, 2, 1)
gmsh.model.geo.addLine(3, 2, 2)
gmsh.model.geo.addLine(3, 4, 3)
gmsh.model.geo.addLine(4, 1, 4)
gmsh.model.geo.addCurveLoop([4, 1, -2, 3], 1)
gmsh.model.geo.addPlaneSurface([1], 1)
gmsh.model.addPhysicalGroup(0, [1, 2], 1)
gmsh.model.addPhysicalGroup(1, [1, 2], 2)
gmsh.model.addPhysicalGroup(2, [1], 6)
gmsh.model.setPhysicalName(2, 6, "My surface")
gmsh.model.geo.synchronize()
gmsh.model.mesh.generate(2)
gmsh.write("t1.msh")
gmsh.finalize()
# Out:
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 30%] Meshing curve 2 (Line)
# Info    : [ 50%] Meshing curve 3 (Line)
# Info    : [ 80%] Meshing curve 4 (Line)
# Info    : Done meshing 1D (Wall 0.00030523s, CPU 0.0003s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.00859807s, CPU 0.008582s)
# Info    : 404 nodes 810 elements
# Info    : Writing 't1.msh'...
# Info    : Done writing 't1.msh'
# Warning : Unknown entity of dimension 0 and tag 1 in physical group 1
# Warning : Unknown entity of dimension 0 and tag 2 in physical group 1
# Warning : Unknown entity of dimension 1 and tag 1 in physical group 2
# Warning : Unknown entity of dimension 1 and tag 2 in physical group 2
# Warning : Unknown entity of dimension 2 and tag 1 in physical group 6

# %% [markdown]
# #### [`t2.jl`](https://gitlab.onelab.info/gmsh/gmsh/-/blob/gmsh_4_12_0/tutorials/julia/t2.jl)

# %%
gmsh.initialize()
gmsh.model.add("t2")
lc = 1e-2
gmsh.model.geo.addPoint(0, 0, 0, lc, 1)
gmsh.model.geo.addPoint(.1, 0,  0, lc, 2)
gmsh.model.geo.addPoint(.1, .3, 0, lc, 3)
gmsh.model.geo.addPoint(0, .3, 0, lc, 4)
gmsh.model.geo.addLine(1, 2, 1)
gmsh.model.geo.addLine(3, 2, 2)
gmsh.model.geo.addLine(3, 4, 3)
gmsh.model.geo.addLine(4, 1, 4)
gmsh.model.geo.addCurveLoop([4, 1, -2, 3], 1)
gmsh.model.geo.addPlaneSurface([1], 1)
gmsh.model.geo.synchronize()
gmsh.model.addPhysicalGroup(1, [1, 2, 4], 5)
gmsh.model.addPhysicalGroup(2, [1], -1, "My surface")
gmsh.model.geo.addPoint(0, .4, 0, lc, 5)
gmsh.model.geo.addLine(4, 5, 5)
gmsh.model.geo.translate([(0, 5)], -0.02, 0, 0)
gmsh.model.geo.rotate([(0, 5)], 0, 0.3, 0, 0, 0, 1, -pi / 4)
ov = gmsh.model.geo.copy([(0, 3)])
gmsh.model.geo.translate(ov, 0, 0.05, 0)

gmsh.model.geo.addLine(3, ov[1][2], 7)
gmsh.model.geo.addLine(ov[1][2], 5, 8)
gmsh.model.geo.addCurveLoop([5, -8, -7, 3], 10)
gmsh.model.geo.addPlaneSurface([10], 11)

ov = gmsh.model.geo.copy([(2, 1), (2, 11)])
gmsh.model.geo.translate(ov, 0.12, 0, 0)

println("New surfaces ", ov[1][2], " and ", ov[2][2])

gmsh.model.geo.addPoint(0., 0.3, 0.12, lc, 100)
gmsh.model.geo.addPoint(0.1, 0.3, 0.12, lc, 101)
gmsh.model.geo.addPoint(0.1, 0.35, 0.12, lc, 102)

gmsh.model.geo.synchronize()
xyz = gmsh.model.getValue(0, 5, [])
gmsh.model.geo.addPoint(xyz[1], xyz[2], 0.12, lc, 103)

gmsh.model.geo.addLine(4, 100, 110)
gmsh.model.geo.addLine(3, 101, 111)
gmsh.model.geo.addLine(6, 102, 112)
gmsh.model.geo.addLine(5, 103, 113)
gmsh.model.geo.addLine(103, 100, 114)
gmsh.model.geo.addLine(100, 101, 115)
gmsh.model.geo.addLine(101, 102, 116)
gmsh.model.geo.addLine(102, 103, 117)

gmsh.model.geo.addCurveLoop([115, -111, 3, 110], 118)
gmsh.model.geo.addPlaneSurface([118], 119)
gmsh.model.geo.addCurveLoop([111, 116, -112, -7], 120)
gmsh.model.geo.addPlaneSurface([120], 121)
gmsh.model.geo.addCurveLoop([112, 117, -113, -8], 122)
gmsh.model.geo.addPlaneSurface([122], 123)
gmsh.model.geo.addCurveLoop([114, -110, 5, 113], 124)
gmsh.model.geo.addPlaneSurface([124], 125)
gmsh.model.geo.addCurveLoop([115, 116, 117, 114], 126)
gmsh.model.geo.addPlaneSurface([126], 127)

gmsh.model.geo.addSurfaceLoop([127, 119, 121, 123, 125, 11], 128)
gmsh.model.geo.addVolume([128], 129)

ov2 = gmsh.model.geo.extrude([ov[2]], 0, 0, 0.12)

gmsh.model.geo.mesh.setSize([(0, 103), (0, 105), (0, 109), (0, 102), (0, 28),
                             (0, 24), (0, 6), (0, 5)], lc * 3)

gmsh.model.geo.synchronize()
gmsh.model.addPhysicalGroup(3, [129, 130], 1, "The volume")
gmsh.model.mesh.generate(3)
gmsh.write("t2.msh")
gmsh.finalize()
# Out:
# New surfaces 12 and 17
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 10%] Meshing curve 3 (Line)
# Info    : [ 10%] Meshing curve 4 (Line)
# Info    : [ 20%] Meshing curve 5 (Line)
# Info    : [ 20%] Meshing curve 7 (Line)
# Info    : [ 20%] Meshing curve 8 (Line)
# Info    : [ 30%] Meshing curve 13 (Line)
# Info    : [ 30%] Meshing curve 14 (Line)
# Info    : [ 30%] Meshing curve 15 (Line)
# Info    : [ 40%] Meshing curve 16 (Line)
# Info    : [ 40%] Meshing curve 18 (Line)
# Info    : [ 40%] Meshing curve 19 (Line)
# Info    : [ 50%] Meshing curve 20 (Line)
# Info    : [ 50%] Meshing curve 110 (Line)
# Info    : [ 50%] Meshing curve 111 (Line)
# Info    : [ 60%] Meshing curve 112 (Line)
# Info    : [ 60%] Meshing curve 113 (Line)
# Info    : [ 60%] Meshing curve 114 (Line)
# Info    : [ 70%] Meshing curve 115 (Line)
# Info    : [ 70%] Meshing curve 116 (Line)
# Info    : [ 70%] Meshing curve 117 (Line)
# Info    : [ 80%] Meshing curve 131 (Line)
# Info    : [ 80%] Meshing curve 132 (Line)
# Info    : [ 80%] Meshing curve 133 (Line)
# Info    : [ 90%] Meshing curve 134 (Line)
# Info    : [ 90%] Meshing curve 136 (Line)
# Info    : [ 90%] Meshing curve 137 (Line)
# Info    : [100%] Meshing curve 141 (Line)
# Info    : [100%] Meshing curve 145 (Line)
# Info    : Done meshing 1D (Wall 0.0087896s, CPU 0.008769s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 11 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 12 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 17 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 119 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 121 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 123 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 125 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 127 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 138 (Surface, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 142 (Surface, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 146 (Surface, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 150 (Surface, Frontal-Delaunay)
# Info    : [100%] Meshing surface 151 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0310773s, CPU 0.031056s)
# Info    : Meshing 3D...
# Info    : 3D Meshing 2 volumes with 2 connected components
# Info    : Tetrahedrizing 319 nodes...
# Info    : Done tetrahedrizing 327 nodes (Wall 0.00248157s, CPU 0.002438s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    : Done reconstructing mesh (Wall 0.0055637s, CPU 0.005519s)
# Info    : Found volume 129
# Info    : It. 0 - 0 nodes created - worst tet radius 2.69809 (nodes removed 0 0)
# Info    : 3D refinement terminated (1478 nodes total):
# Info    :  - 0 Delaunay cavities modified for star shapeness
# Info    :  - 0 nodes could not be inserted
# Info    :  - 1216 tetrahedra created in 0.00318024 sec. (382361 tets/s)
# Info    : 0 node relocations
# Info    : Tetrahedrizing 316 nodes...
# Info    : Done tetrahedrizing 324 nodes (Wall 0.00261775s, CPU 0.002617s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    : Done reconstructing mesh (Wall 0.00535673s, CPU 0.005358s)
# Info    : Found volume 130
# Info    : It. 0 - 0 nodes created - worst tet radius 2.82349 (nodes removed 0 0)
# Info    : 3D refinement terminated (1479 nodes total):
# Info    :  - 0 Delaunay cavities modified for star shapeness
# Info    :  - 0 nodes could not be inserted
# Info    :  - 1222 tetrahedra created in 0.00333457 sec. (366464 tets/s)
# Info    : 0 node relocations
# Info    : Done meshing 3D (Wall 0.0345607s, CPU 0.034505s)
# Info    : Optimizing mesh...
# Info    : Optimizing volume 129
# Info    : Optimization starts (volume = 0.000639411) with worst = 0.0204419 / average = 0.726495:
# Info    : 0.00 < quality < 0.10 :         9 elements
# Info    : 0.10 < quality < 0.20 :        14 elements
# Info    : 0.20 < quality < 0.30 :        24 elements
# Info    : 0.30 < quality < 0.40 :        22 elements
# Info    : 0.40 < quality < 0.50 :        30 elements
# Info    : 0.50 < quality < 0.60 :       115 elements
# Info    : 0.60 < quality < 0.70 :       206 elements
# Info    : 0.70 < quality < 0.80 :       361 elements
# Info    : 0.80 < quality < 0.90 :       281 elements
# Info    : 0.90 < quality < 1.00 :       154 elements
# Info    : 46 edge swaps, 2 node relocations (volume = 0.000639411): worst = 0.303396 / average = 0.747278 (Wall 0.0006721s, CPU 0.000673s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :        20 elements
# Info    : 0.40 < quality < 0.50 :        33 elements
# Info    : 0.50 < quality < 0.60 :       116 elements
# Info    : 0.60 < quality < 0.70 :       216 elements
# Info    : 0.70 < quality < 0.80 :       354 elements
# Info    : 0.80 < quality < 0.90 :       287 elements
# Info    : 0.90 < quality < 1.00 :       152 elements
# Info    : Optimizing volume 130
# Info    : Optimization starts (volume = 0.000639411) with worst = 0.0196513 / average = 0.71957:
# Info    : 0.00 < quality < 0.10 :         3 elements
# Info    : 0.10 < quality < 0.20 :        19 elements
# Info    : 0.20 < quality < 0.30 :        17 elements
# Info    : 0.30 < quality < 0.40 :        33 elements
# Info    : 0.40 < quality < 0.50 :        45 elements
# Info    : 0.50 < quality < 0.60 :       120 elements
# Info    : 0.60 < quality < 0.70 :       201 elements
# Info    : 0.70 < quality < 0.80 :       372 elements
# Info    : 0.80 < quality < 0.90 :       261 elements
# Info    : 0.90 < quality < 1.00 :       151 elements
# Info    : 38 edge swaps, 0 node relocations (volume = 0.000639411): worst = 0.169257 / average = 0.735911 (Wall 0.00050372s, CPU 0.000504s)
# Info    : 41 edge swaps, 0 node relocations (volume = 0.000639411): worst = 0.302241 / average = 0.736537 (Wall 0.000620209s, CPU 0.00062s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :        26 elements
# Info    : 0.40 < quality < 0.50 :        54 elements
# Info    : 0.50 < quality < 0.60 :       127 elements
# Info    : 0.60 < quality < 0.70 :       196 elements
# Info    : 0.70 < quality < 0.80 :       376 elements
# Info    : 0.80 < quality < 0.90 :       262 elements
# Info    : 0.90 < quality < 1.00 :       148 elements
# Info    : Done optimizing mesh (Wall 0.00340482s, CPU 0.003405s)
# Info    : 1534 nodes 5393 elements
# Info    : Writing 't2.msh'...
# Info    : Done writing 't2.msh'

# %% [markdown]
# #### [`t3.jl`](https://gitlab.onelab.info/gmsh/gmsh/-/blob/gmsh_4_12_0/tutorials/julia/t3.jl)

# %%
gmsh.initialize()

function createGeometryAndMesh()
    gmsh.clear()
    gmsh.model.add("t3")
    lc = 1e-2
    gmsh.model.geo.addPoint(0, 0, 0, lc, 1)
    gmsh.model.geo.addPoint(.1, 0,  0, lc, 2)
    gmsh.model.geo.addPoint(.1, .3, 0, lc, 3)
    gmsh.model.geo.addPoint(0, .3, 0, lc, 4)
    gmsh.model.geo.addLine(1, 2, 1)
    gmsh.model.geo.addLine(3, 2, 2)
    gmsh.model.geo.addLine(3, 4, 3)
    gmsh.model.geo.addLine(4, 1, 4)
    gmsh.model.geo.addCurveLoop([4, 1, -2, 3], 1)
    gmsh.model.geo.addPlaneSurface([1], 1)
    gmsh.model.geo.synchronize()
    gmsh.model.addPhysicalGroup(1, [1, 2, 4], 5)
    gmsh.model.addPhysicalGroup(2, [1], -1, "My surface")
    h = 0.1
    angle = 90.
    ov = gmsh.model.geo.extrude([(2, 1)], 0, 0, h, [8, 2], [0.5, 1])
    ov = gmsh.model.geo.revolve([(2, 28)], -0.1, 0, 0.1, 0, 1, 0, -pi / 2, [7])
    angle = gmsh.onelab.getNumber("Parameters/Twisting angle")[1]
    ov = gmsh.model.geo.twist([(2, 50)], 0, 0.15, 0.25, -2 * h, 0, 0, 1, 0, 0,
                              angle * pi / 180., [10], [], true)
    gmsh.model.geo.synchronize()
    gmsh.model.addPhysicalGroup(3, [1, 2, ov[2][2]], 101)
    gmsh.model.mesh.generate(3)
    gmsh.write("t3.msh")
end

gmsh.option.setNumber("Geometry.PointNumbers", 1)
gmsh.option.setColor("Geometry.Color.Points", 255, 165, 0)
gmsh.option.setColor("General.Color.Text", 255, 255, 255)
gmsh.option.setColor("Mesh.Color.Points", 255, 0, 0)

r, g, b, a = gmsh.option.getColor("Geometry.Points")
gmsh.option.setColor("Geometry.Surfaces", r, g, b, a)

gmsh.onelab.set("""[
  {
    "type":"number",
    "name":"Parameters/Twisting angle",
    "values":[90],
    "min":0,
    "max":120,
    "step":1
  }
]""")

createGeometryAndMesh()
gmsh.write("t3.opt");
gmsh.finalize()
# Out:
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 10%] Meshing curve 3 (Line)
# Info    : [ 20%] Meshing curve 4 (Line)
# Info    : [ 20%] Meshing curve 8 (Extruded)
# Info    : [ 20%] Meshing curve 9 (Extruded)
# Info    : [ 30%] Meshing curve 10 (Extruded)
# Info    : [ 30%] Meshing curve 11 (Extruded)
# Info    : [ 30%] Meshing curve 13 (Extruded)
# Info    : [ 40%] Meshing curve 14 (Extruded)
# Info    : [ 40%] Meshing curve 18 (Extruded)
# Info    : [ 40%] Meshing curve 22 (Extruded)
# Info    : [ 50%] Meshing curve 30 (Extruded)
# Info    : [ 50%] Meshing curve 31 (Extruded)
# Info    : [ 50%] Meshing curve 32 (Extruded)
# Info    : [ 60%] Meshing curve 33 (Extruded)
# Info    : [ 60%] Meshing curve 35 (Extruded)
# Info    : [ 70%] Meshing curve 36 (Extruded)
# Info    : [ 70%] Meshing curve 40 (Extruded)
# Info    : [ 70%] Meshing curve 44 (Extruded)
# Info    : [ 80%] Meshing curve 52 (Extruded)
# Info    : [ 80%] Meshing curve 53 (Extruded)
# Info    : [ 80%] Meshing curve 54 (Extruded)
# Info    : [ 90%] Meshing curve 55 (Extruded)
# Info    : [ 90%] Meshing curve 57 (Extruded)
# Info    : [ 90%] Meshing curve 58 (Extruded)
# Info    : [100%] Meshing curve 62 (Extruded)
# Info    : [100%] Meshing curve 66 (Extruded)
# Info    : Done meshing 1D (Wall 0.00047401s, CPU 0.000475s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 15 (Extruded)
# Info    : [ 20%] Meshing surface 19 (Extruded)
# Info    : [ 20%] Meshing surface 23 (Extruded)
# Info    : [ 30%] Meshing surface 27 (Extruded)
# Info    : [ 40%] Meshing surface 28 (Extruded)
# Info    : [ 40%] Meshing surface 37 (Extruded)
# Info    : [ 50%] Meshing surface 41 (Extruded)
# Info    : [ 50%] Meshing surface 45 (Extruded)
# Info    : [ 60%] Meshing surface 49 (Extruded)
# Info    : [ 70%] Meshing surface 50 (Extruded)
# Info    : [ 70%] Meshing surface 59 (Extruded)
# Info    : [ 80%] Meshing surface 63 (Extruded)
# Info    : [ 90%] Meshing surface 67 (Extruded)
# Info    : [ 90%] Meshing surface 71 (Extruded)
# Info    : [100%] Meshing surface 72 (Extruded)
# Info    : Done meshing 2D (Wall 0.0291026s, CPU 0.029081s)
# Info    : Meshing 3D...
# Info    : Meshing volume 1 (Extruded)
# Info    : Meshing volume 2 (Extruded)
# Info    : Meshing volume 3 (Extruded)
# Info    : Subdividing extruded mesh
# Info    : Swapping 323
# Info    : Swapping 51
# Info    : Swapping 0
# Info    : Remeshing surface 27
# Info    : Meshing surface 27 (Extruded)
# Info    : Remeshing surface 45
# Info    : Meshing surface 45 (Extruded)
# Info    : Remeshing surface 23
# Info    : Meshing surface 23 (Extruded)
# Info    : Remeshing surface 37
# Info    : Meshing surface 37 (Extruded)
# Info    : Remeshing surface 15
# Info    : Meshing surface 15 (Extruded)
# Info    : Remeshing surface 19
# Info    : Meshing surface 19 (Extruded)
# Info    : Remeshing surface 49
# Info    : Meshing surface 49 (Extruded)
# Info    : Remeshing surface 41
# Info    : Meshing surface 41 (Extruded)
# Info    : Done meshing 3D (Wall 0.255123s, CPU 0.25512s)
# Info    : Optimizing mesh...
# Info    : Done optimizing mesh (Wall 0.00095911s, CPU 0.000959s)
# Info    : 11330 nodes 51172 elements
# Info    : Writing 't3.msh'...
# Info    : Done writing 't3.msh'
# Info    : Writing 't3.opt'...
# Info    : Done writing 't3.opt'

# %%
run(`ls`) # readdir()
# Out:
# Manifest.toml
# Project.toml
# t1.msh
# t2.msh
# t3.msh
# t3.opt
# tutorials.ipynb
# updater.sh
# Process(`ls`, ProcessExited(0))
